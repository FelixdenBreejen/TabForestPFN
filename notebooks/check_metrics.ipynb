# %%
import xarray as xr

# %%
ds = xr.open_dataset("outputs/2024-03-07/13-08-14/foundation-default-debug_categorical_classification/results_sweep.nc")
ds
# Out:
# <xarray.Dataset>
# Dimensions:              (openml_dataset_id: 3, data_split: 3, run_id: 1,
#                           cv_split: 3)
# Coordinates:
#   * data_split           (data_split) object 'train' 'valid' 'test'
#   * openml_dataset_id    (openml_dataset_id) int32 44156 45035 45039
#   * cv_split             (cv_split) int32 0 1 2
#   * run_id               (run_id) int32 0
# Data variables:
#     openml_dataset_name  (openml_dataset_id) object ...
#     search_type          (openml_dataset_id, run_id) object ...
#     score                (openml_dataset_id, run_id, cv_split, data_split) float64 ...
#     loss                 (openml_dataset_id, run_id, cv_split, data_split) float64 ...
#     accuracy             (openml_dataset_id, run_id, cv_split, data_split) float64 ...
#     f1                   (openml_dataset_id, run_id, cv_split, data_split) float64 ...
#     auc                  (openml_dataset_id, run_id, cv_split, data_split) float64 ...
#     log_loss             (openml_dataset_id, run_id, cv_split, data_split) float64 ...
#     seed                 (openml_dataset_id, run_id) int32 ...
#     cv_splits_actual     (openml_dataset_id) int32 ...
#     runs_actual          (openml_dataset_id) int32 ...
# Attributes:
#     model_name:  Foundation
#     task:        classification

# %%
ds_run = xr.open_dataset("outputs/2024-03-07/13-08-14/foundation-default-debug_categorical_classification/44156/#0/metrics.nc")
ds_run
# Out:
# <xarray.Dataset>
# Dimensions:     (data_split: 3, cv_split: 1)
# Coordinates:
#   * data_split  (data_split) object 'train' 'valid' 'test'
#   * cv_split    (cv_split) int32 0
# Data variables:
#     score       (cv_split, data_split) float64 ...
#     loss        (cv_split, data_split) float64 ...
#     accuracy    (cv_split, data_split) float64 ...
#     f1          (cv_split, data_split) float64 ...
#     auc         (cv_split, data_split) float64 ...
#     log_loss    (cv_split, data_split) float64 ...

# %%
ds = xr.open_dataset("data/benchmark_total_reformatted.nc")
dsW
# Out:
# <xarray.Dataset>
# Dimensions:              (run_id: 2376, openml_dataset_id: 59, model_name: 8,
#                           cv_split: 5, data_split: 3)
# Coordinates:
#   * run_id               (run_id) int32 0 1 2 3 4 5 ... 2371 2372 2373 2374 2375
#   * openml_dataset_id    (openml_dataset_id) int32 44055 44056 ... 45047 45048
#   * model_name           (model_name) object 'RandomForest' ... 'HistGradient...
#   * cv_split             (cv_split) int32 0 1 2 3 4
#   * data_split           (data_split) object 'train' 'valid' 'test'
# Data variables:
#     search_type          (openml_dataset_id, run_id) object ...
#     openml_dataset_name  (openml_dataset_id) object ...
#     benchmark_name       (openml_dataset_id) object ...
#     task                 (openml_dataset_id) object ...
#     feature_type         (openml_dataset_id) object ...
#     dataset_size         (openml_dataset_id) object ...
#     cv_splits_actual     (openml_dataset_id) int32 ...
#     score                (model_name, openml_dataset_id, run_id, cv_split, data_split) float64 ...
#     accuracy             (model_name, openml_dataset_id, run_id, cv_split, data_split) float64 ...
#     r2                   (model_name, openml_dataset_id, run_id, cv_split, data_split) float64 ...
#     runs_actual          (model_name, openml_dataset_id) int32 ...
# Attributes:
#     description:  Reformatted whytrees benchmark, from the paper "Why do tree...
#     details:      Score is the same as accuracy and r2, depending on the task...

# %%
ds['runs_actual'].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 ds['runs_actual'].plot()
#
# File ~/anaconda3/envs/tab/lib/python3.11/site-packages/xarray/plot/accessor.py:48, in DataArrayPlotAccessor.__call__(self, **kwargs)
#      46 @functools.wraps(dataarray_plot.plot, assigned=("__doc__", "__annotations__"))
#      47 def __call__(self, **kwargs) -> Any:
# ---> 48     return dataarray_plot.plot(self._da, **kwargs)
#
# File ~/anaconda3/envs/tab/lib/python3.11/site-packages/xarray/plot/dataarray_plot.py:309, in plot(darray, row, col, col_wrap, ax, hue, subplot_kws, **kwargs)
#     305     plotfunc = hist
#     307 kwargs["ax"] = ax
# --> 309 return plotfunc(darray, **kwargs)
#
# File ~/anaconda3/envs/tab/lib/python3.11/site-packages/xarray/plot/dataarray_plot.py:1576, in _plot2d.<locals>.newplotfunc(***failed resolving arguments***)
#    1573 xplt, xlab_extra = _resolve_intervals_2dplot(xvalnp, plotfunc.__name__)
#    1574 yplt, ylab_extra = _resolve_intervals_2dplot(yvalnp, plotfunc.__name__)
# -> 1576 _ensure_plottable(xplt, yplt, zval)
#    1578 cmap_params, cbar_kwargs = _process_cmap_cbar_kwargs(
#    1579     plotfunc,
#    1580     zval.data,
#    1581     **locals(),
#    1582     _is_facetgrid=kwargs.pop("_is_facetgrid", False),
#    1583 )
#    1585 if "contour" in plotfunc.__name__:
#    1586     # extend is a keyword argument only for contour and contourf, but
#    1587     # passing it to the colorbar is sufficient for imshow and
#    1588     # pcolormesh
#
# File ~/anaconda3/envs/tab/lib/python3.11/site-packages/xarray/plot/utils.py:686, in _ensure_plottable(*args)
#     681 for x in args:
#     682     if not (
#     683         _valid_numpy_subdtype(np.asarray(x), numpy_types)
#     684         or _valid_other_type(np.asarray(x), other_types)
#     685     ):
# --> 686         raise TypeError(
#     687             "Plotting requires coordinates to be numeric, boolean, "
#     688             "or dates of type numpy.datetime64, "
#     689             "datetime.datetime, cftime.datetime or "
#     690             f"pandas.Interval. Received data of type {np.asarray(x).dtype} instead."
#     691         )
#     692     if _valid_other_type(np.asarray(x), cftime_datetime_types):
#     693         if nc_time_axis_available:
#     694             # Register cftime datetypes to matplotlib.units.registry,
#     695             # otherwise matplotlib will raise an error:
#
# TypeError: Plotting requires coordinates to be numeric, boolean, or dates of type numpy.datetime64, datetime.datetime, cftime.datetime or pandas.Interval. Received data of type object instead.

# %% [markdown]
# 171536/367597
