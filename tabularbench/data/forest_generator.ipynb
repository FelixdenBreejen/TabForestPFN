# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from tabularbench.data.synthetic_generator_forest import synthetic_dataset_generator as synthetic_dataset_generator_forest
import numpy as np
import matplotlib.pyplot as plt

x2, b = synthetic_dataset_generator_forest()

fig, axes = plt.subplots(8, 6, figsize=(20, 15))

for ax in axes.flatten():
    x2, b = synthetic_dataset_generator_forest(base_size=1000, min_features=2, max_features=2)
    i1, i2 = np.random.choice(x2.shape[1], size=(2,), replace=False)
    ax.scatter(x2[:, i1], x2[:, i2], c=b)

# %%
# %timeit -n 1 -r 1000 synthetic_dataset_generator_forest(base_size=1000)
# Out:
# The slowest run took 61.46 times longer than the fastest. This could mean that an intermediate result is being cached.
# 113 ms ± 78.7 ms per loop (mean ± std. dev. of 1000 runs, 1 loop each)

# %%
from tabularbench.data.synthetic_generator_tabpfn import synthetic_dataset_generator as synthetic_data_generator_tabpfn


gen = synthetic_data_generator_tabpfn(
    n_samples = 10000,
    min_features = 3,
    max_features = 133,
    max_classes = 10
)

# %timeit -n 1 -r 1000 next(gen)
# Out:
# The slowest run took 27.27 times longer than the fastest. This could mean that an intermediate result is being cached.
# 104 ms ± 66.1 ms per loop (mean ± std. dev. of 1000 runs, 1 loop each)
