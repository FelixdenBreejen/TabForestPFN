# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tabularbench.data.synthetic_generator_forest import synthetic_dataset_generator_forest, synthetic_dataset_function_forest
import numpy as np
import matplotlib.pyplot as plt

fig, axes = plt.subplots(8, 6, figsize=(20, 15))

for ax in axes.flatten():
    x2, b = synthetic_dataset_function_forest(base_size=1000, min_features=2, max_features=2, min_depth=1, max_depth=25, categorical_x=False)
    i1, i2 = np.random.choice(x2.shape[1], size=(2,), replace=False)
    ax.scatter(x2[:, i1], x2[:, i2], c=b)

# %%
from tabularbench.data.synthetic_generator_tabpfn import synthetic_dataset_generator_tabpfn

fig, axes = plt.subplots(8, 6, figsize=(20, 15))
generator = synthetic_dataset_generator_tabpfn(n_samples=10000, max_classes=10, min_features=2, max_features=2)

for ax in axes.flatten():
    x2, b = next(generator)
    i1, i2 = np.random.choice(x2.shape[1], size=(2,), replace=False)
    ax.scatter(x2[:, i1], x2[:, i2], c=b)

# %%
from tabularbench.data.synthetic_generator_cuts import synthetic_dataset_function_cuts 
import numpy as np
import matplotlib.pyplot as plt

fig, axes = plt.subplots(8, 6, figsize=(20, 15))

for ax in axes.flatten():
    x2, b = synthetic_dataset_function_cuts(min_features=2, max_features=2, n_cuts=1000)
    i1, i2 = np.random.choice(x2.shape[1], size=(2,), replace=False)
    ax.scatter(x2[:, i1], x2[:, i2], c=b)

# %%
from tabularbench.data.synthetic_generator_neighbor import synthetic_dataset_function_neighbor
import numpy as np
import matplotlib.pyplot as plt

fig, axes = plt.subplots(8, 6, figsize=(20, 15))

for ax in axes.flatten():
    x2, b = synthetic_dataset_function_neighbor(min_features=2, max_features=2, min_neighbors=256, max_neighbors=1024)
    i1, i2 = np.random.choice(x2.shape[1], size=(2,), replace=False)
    ax.scatter(x2[:, i1], x2[:, i2], c=b)

# %%
from tabularbench.data.synthetic_generator_forest import synthetic_dataset_generator_forest

gen = synthetic_dataset_generator_forest(base_size=1000, min_features=3, max_features=100, min_depth=15, max_depth=25)

# %timeit -n 1 -r 1000 next(gen)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 5
#       1 from tabularbench.data.synthetic_generator_forest import synthetic_dataset_generator_forest
#       3 gen = synthetic_dataset_generator_forest(base_size=1000, min_features=3, max_features=100, min_depth=15, max_depth=25)
# ----> 5 get_ipython().run_line_magic('timeit', '-n 1 -r 1000 next(gen)')
#
# File ~/anaconda3/envs/tab/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2454, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2452     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2453 with self.builtin_trap:
# -> 2454     result = fn(*args, **kwargs)
#    2456 # The code below prevents the output from being displayed
#    2457 # when using magics with decorator @output_can_be_silenced
# ...

# %%
from tabularbench.data.synthetic_generator_neighbor import synthetic_dataset_generator_neighbor

gen = synthetic_dataset_generator_neighbor(min_features=3, max_features=100)

# %timeit -n 1 -r 1000 next(gen)
# Out:
# The slowest run took 57.90 times longer than the fastest. This could mean that an intermediate result is being cached.
# 105 ms ± 65.6 ms per loop (mean ± std. dev. of 1000 runs, 1 loop each)
