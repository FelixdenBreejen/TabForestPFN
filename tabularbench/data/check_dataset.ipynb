# %%
import xarray as xr
from pathlib import Path

path = Path('data/openml/tabzilla_168335.nc')
ds = xr.open_dataset(path)
ds
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/tab/lib/python3.11/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File ~/anaconda3/envs/tab/lib/python3.11/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<function _open_scipy_netcdf at 0x7f9c7a0f7b00>, ('/home/felix/tabularbench/data/openml/tabzilla_168335.nc',), 'r', (('mmap', None), ('version', 2)), '4123818c-5d85-4dda-ac20-209491b3eb10']
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ...
