# %%
import xarray as xr
from pathlib import Path

path = Path('data/openml/44157_MEDIUM.nc')
ds = xr.open_dataset(path)
ds
# Out:
# <xarray.Dataset>
# Dimensions:                (observation: 7608, feature: 23, split: 3)
# Coordinates:
#   * observation            (observation) int32 0 1 2 3 4 ... 7604 7605 7606 7607
#   * feature                (feature) int32 0 1 2 3 4 5 6 ... 17 18 19 20 21 22
#   * split                  (split) int32 0 1 2
# Data variables:
#     x                      (observation, feature) float32 ...
#     split_index_train      (observation, split) bool ...
#     split_index_val        (observation, split) bool ...
#     split_index_test       (observation, split) bool ...
#     y                      (observation) int32 ...
#     attribute_names        (feature) object ...
#     categorical_indicator  (feature) bool ...
# Attributes:
#     openml_dataset_id:    44157
#     openml_dataset_name:  eye_movements
